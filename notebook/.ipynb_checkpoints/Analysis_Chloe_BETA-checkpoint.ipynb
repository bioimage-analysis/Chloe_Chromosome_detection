# %%
# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 8,8
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
import numpy as np
import javabridge
import bioformats

# %%
# Ignore warnings in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
cd ..
# Out:
# /Users/Espenel/Desktop/Mini-Grant-Image-analysis/2018/Chloe/ChromosomeDetectionChloe

# %%
from utils import *

# %%
javabridge.start_vm(class_path=bioformats.JARS)

# %%
path = '/Users/Espenel/Desktop/Mini-Grant-Image-analysis/2018/Chloe/cku-exo1_002/2017-04-12_RAD51-HTP3_cku80-exo1_002_visit_12_D3D_ALX.dv'

# %%
image = load_data.load_bioformats(path)

# %%
javabridge.kill_vm()

# %%
img = image[:,:,:,3]

# %%
visualization.browse_images(img)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# # Background substraction

# %%
ch1 = img_analysis.roll_ball(image, ch=1, size=5)

# %%
ch2 = img_analysis.roll_ball(image, ch=2, size=5)

# %%
ch3 = img_analysis.roll_ball(image)

# %% [markdown]
# # Find Blobs

# %%
from skimage.feature import blob_log

# %%
blobs = blob_log(ch1,  min_sigma=1, max_sigma=5, threshold=0.08, overlap=0, log_scale=True)

# %%
blobs.shape
# Out:
# (455, 4)

# %%
# Max intensity projection to visualyse all the blobs
mip = np.amax(ch1, axis=0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.imshow(mip, vmax=0.3)
for blob in blobs:    
    z,x,y,s = blob
    ax.scatter(y, x, s=s*50, facecolors='none', edgecolors='r')

# %%
visualization.browse_blobs(ch1, blobs)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
title = []
for x in range(len(ch3)):
    title.append("Z_step_{}".format(x+1))

# %%
visualization.plot_mosaic(ch3, title)

# %%
binary = img_analysis.binarization(ch3)

# %%
visualization.browse_images(binary)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
from skimage import morphology
from skimage.draw import circle

# %%
bbox_ML = np.load("/Users/Espenel/Desktop/Mini-Grant-Image-analysis/2018/Chloe/12/bbox_3D_test.npy")

# %%
masked = img_analysis.find_foci(blobs, ch3, binary)

# %% [markdown]
# # Find number of foci per cells

# %% [markdown]
# ### Create an ellipse mask around position of nucleus and give number of foci per nucleus

# %%
res = search.binary_select_foci(bbox_ML, ch3, masked)

# %% [markdown]
# ### Then we find all the foci that were count twice

# %%
num, cts, dup_idx, mask = search.find_duplicate(res)

# %% [markdown]
# ### Remove foci counted twice

# %%
if dup_idx[0].size == 0:
    new_cts = cts
else:
    new_cts = search.remove_duplicate(cts, dup_idx, res)

# %% [markdown]
# ### We can plot the result

# %%
mip_ch3 = np.amax(ch3,axis=0)

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.imshow(mip_ch3, vmax=0.3)
for coord, val, cell in zip(bbox_ML,cts, num):
    circles1 = patches.Circle((coord[0]+35,coord[1]+35),30, linewidth=3,edgecolor='r',facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(circles1)
    ax.text(coord[0]+15,coord[1], "Cell_{}".format(str(cell)),color = 'r', weight='bold')
    ax.text(coord[0]+15,coord[1]+35, "{} COSA-1".format(str(val)),color = 'w', weight='bold')

plt.legend([circles1], ["No Duplicate"],loc=1,fontsize='small')

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.imshow(mip_ch3, vmax=0.3)
for coord, val, cell in zip(bbox_ML[~mask],cts[~mask], num[~mask]):
    circles1 = patches.Circle((coord[0]+35,coord[1]+35),30, linewidth=3,edgecolor='r',facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(circles1)
    ax.text(coord[0]+15,coord[1], "Cell_{}".format(str(cell)),color = 'r', weight='bold')
    ax.text(coord[0]+15,coord[1]+35, "{} COSA-1".format(str(val)),color = 'w', weight='bold')
for coord, val, cell in zip(bbox_ML[mask],cts[mask], num[mask]):
    circles2 = patches.Circle((coord[0]+35,coord[1]+35),30, linewidth=3,edgecolor='y',facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(circles2)
    ax.text(coord[0]+15,coord[1], "Cell_{}".format(str(cell)),color = 'y', weight='bold')
    ax.text(coord[0]+15,coord[1]+35, "{} COSA-1".format(str(val)),color = 'w', weight='bold')

plt.legend([circles1,circles2], ["No Duplicate","Duplicate"],loc=1,fontsize='small')
    
#plt.savefig('Chloe_result_chrom_3D.png',dpi=200)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-bf18cab5e93d> in <module>()
#       2 fig, ax = plt.subplots(1, 1, figsize=(10, 10))
#       3 ax.imshow(mip_ch3, vmax=0.3)
# ----> 4 for coord, val, cell in zip(bbox_ML[~mask],cts[~mask], num[~mask]):
#       5     circles1 = patches.Circle((coord[0]+35,coord[1]+35),30, linewidth=3,edgecolor='r',facecolor='none')
#       6     # Add the patch to the Axes
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 19 but corresponding boolean dimension is 26

# %%
import matplotlib
z = [i for i in range(0,cts.max()+1)]
cmap = matplotlib.cm.get_cmap('viridis')
normalize = matplotlib.colors.Normalize(vmin=min(z), vmax=max(z))

colors = [cmap(normalize(value)) for value in z]

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.imshow(mip_ch3, vmax=0.3)

s = np.pi*(35**2)

for coord, val, cell in zip(bbox_ML,cts, num):
    ax.scatter(coord[0]+35,coord[1]+35, s=s, c=colors[val], alpha=0.7)
    # Add the patch to the Axes
    #ax.text(coord[0]+15,coord[1], "Cell_{}".format(str(cell)),color = 'r', weight='bold')
    #ax.text(coord[0]+15,coord[1]+35, "{} COSA-1".format(str(val)),color = 'w', weight='bold')
cax, _ = matplotlib.colorbar.make_axes(ax)
cbar = matplotlib.colorbar.ColorbarBase(cax, cmap=cmap, norm=normalize)
cbar.ax.set_ylabel('Number of FOCI',labelpad=10, rotation=270)
#plt.savefig('Chloe_result_chrom_3D_Heat_MAP.png',dpi=200)
# Out:
# Text(0,0.5,'Number of FOCI')

# %%
mu = np.mean(new_cts)
sigma = np.std(new_cts)

# %%
import matplotlib.mlab as mlabs
fig, ax = plt.subplots()
bins = np.max(new_cts)
result = ax.hist(new_cts, bins = bins, edgecolor='black')
for i in range(bins):
    ax.text(result[1][i]+0.3,result[0][i]+0.3,str(int(result[0][i])))
x = np.linspace(min(new_cts), max(new_cts), 100)
dx = result[1][1] - result[1][0]
scale = len(new_cts)*dx
ax.plot(x, mlabs.normpdf(x, mu, sigma)*scale)
ax.set_xlabel('Number of COSA-1 per cell')
ax.set_title(r'Histogram of FOCI distribution $\mu={}$, $\sigma={}$'.format(round(mu,1), round(sigma,1)))
#plt.savefig('foci_dist.png',dpi=150)
# Out:
# Text(0.5,1,'Histogram of FOCI distribution $\\mu=4.7$, $\\sigma=2.7$')

# %%
bbox_ML[0]
# Out:
# array([288.,  64., 358., 134.,  64.])

# %%
np.save("ex_bbox_12", bbox_ML)
np.save("ex_cts_12", cts)

# %%
from skimage import io

# %%
io.imsave("coins.tif", image)

# %%
import matplotlib.pyplot as plt

from skimage import data
from skimage.morphology import disk
from skimage.filters import rank
from skimage.morphology import opening


image = data.coins()
selem = disk(80)

y0, x0 = 270, 0
y1, x1 = 270, 400

median_result = rank.median(image, selem=selem)
tophat = rank.tophat(image, selem=selem)
normal_result = rank.mean(image, selem=selem)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10),
                         sharex=True, sharey=True)
ax = axes.ravel()

titles = ['Original', 'Median', 'tophat', 'Local mean']
imgs = [image, image.astype('float64') - median_result.astype('float64'), tophat, image.astype('float64') - normal_result.astype('float64')]
for n in range(0, len(imgs)):
    ax[n].imshow(imgs[n], cmap=plt.cm.gray)
    ax[n].plot([x0, x1], [y0, y1], 'ro-')
    ax[n].set_title(titles[n])
    ax[n].axis('off')

plt.tight_layout()

# %%
image[270, 80].astype('float64') - normal_result[270, 80].astype('float64')
# Out:
# -33.0

# %%
normal_result[270, 80]
# Out:
# 84

# %%
plt.plot(tophat[270, :])

# %%
plt.plot(normal_result[270, :])
plt.plot(image[270, :])

# %%
plt.plot(image[270, :].astype('float64')- normal_result[270, :].astype('float64'))

# %%
import numpy as np
from skimage.morphology import opening

# %%
op = opening(image, selem)

# %%
wth = image-op

# %%
image.shape
# Out:
# (303, 384)

# %%
di = np.diag_indices(303,384, ndim = 2)
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-52-e20dead022b2> in <module>()
# ----> 1 di = np.diag_indices(303,384, ndim = 2)
#
# TypeError: diag_indices() got multiple values for argument 'ndim'

# %%
image[di] = 0

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 10), sharex=True,
                                   sharey=True)

ax1.imshow(image, cmap=plt.cm.gray)
ax2.imshow(wth, cmap=plt.cm.gray)

# %%
from scipy import ndimage
background =  ndimage.convolve(image, selem, mode='constant', cval=0.0)

# %%
im.max()
# Out:
# 0.6181055138631393

# %%
background.max()
# Out:
# 750.2790119431542

# %%
plt.imshow(image, cmap=plt.cm.gray)
